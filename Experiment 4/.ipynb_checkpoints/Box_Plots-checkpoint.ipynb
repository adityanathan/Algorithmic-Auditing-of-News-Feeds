# %%
import pandas as pd
import numpy as np
import pickle
import re
import timeit
import spacy
import copy

import gensim
import gensim.corpora as corpora
from gensim.corpora import Dictionary
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel, HdpModel, LdaModel, LdaMulticore
from nltk.corpus import stopwords
import helper as he
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid") 

with open('../data/preprocessed_data/doc_indexes/gst.pkl','rb') as f:
    texts,INITIAL_DOC_SIZE, DOC_TEMPORAL_INCREMENT = pickle.load(f)

with open('../data/preprocessed_data/corpus_dict/gst_corp.pkl', 'rb') as f:
    data_lemmatized, _, _ = pickle.load(f)

# %%
print('Building Dictionary')
#Dictionary is built over entire set of documents
id2word = Dictionary(documents=data_lemmatized)
# Out:
# Building Dictionary

# %%
#Golden Standard Model
print('Building Golden Corpus')
golden_corpus = [id2word.doc2bow(doc) for doc in data_lemmatized]
golden_lda = LdaMulticore(golden_corpus, num_topics=35, id2word=id2word,
                   workers=3, chunksize=2000, passes=10, batch=False)
print('Finished Building Golden Corpus')
# Out:
# Building Golden Corpus
# Finished Building Golden Corpus

# %%
# Out:
# Building Initial Model
# Finished Building Initial Model

# %%
def get_positives_arr(initial_doc_size, doc_increment):
    
    # Set Data State to that of existing model in simulation
    data = data_lemmatized[:initial_doc_size]
    corpus = [id2word.doc2bow(doc) for doc in data]

    print('Building Initial Model')
    # Building for the first time - To be considered as the starting/existing model in simulation.
    running_lda = LdaMulticore(corpus, num_topics=35, id2word=id2word,
                       workers=3, chunksize=2000, passes=10, batch=False)
    print('Finished Building Initial Model')
    
    
    count = initial_doc_size
    positive_arr=[]
    no=0
    total_len=len(data_lemmatized)
    for i in doc_increment:
        no+=1
        new_docs = data_lemmatized[count:count+i]
        count+=i
        print('Progress upto Document no.',count,'/',total_len)
        print('No. of New Docs:',i)

        new_corp = [id2word.doc2bow(doc) for doc in new_docs]

        positive_arr.append(calc_confusion_matrix(golden_lda, running_lda, new_corp))
        
        if(i!=doc_increment[-1]):
            print('MODEL NO:'+str(no))
            running_lda.update(new_corp)
            print('MODEL DONE')
    return positive_arr

# %%
def get_doc_parameters(initial,k):
    arr = []
    arr.append(INITIAL_DOC_SIZE)
    arr.extend(DOC_TEMPORAL_INCREMENT)
    for i in range(1,len(arr)):
        arr[i]=arr[i]+arr[i-1]
        
    doc_sizes = []
    count=1
    for i in range(initial+1,len(arr)):
        if(count%k==0):
            doc_sizes.append(arr[i])
            count=1
        count+=1
        
    doc_intervals = [arr[initial],doc_sizes[0]-arr[initial]]
    for i in range(1,len(doc_sizes)):
        doc_intervals.append(doc_sizes[i]-doc_sizes[i-1])
    
    return doc_intervals

# %%
def add_row_to_df(df,positive_arr,k):
    length = len(df)
    count=length
    for i in positive_arr:
        df.loc[count]=[i,count-length,k]
        count+=1
    return df

# %%
def calc_confusion_matrix(model1, model2, corpus1, doc_max=True):
    lda_corpus_1 = [max(prob, key=lambda y:y[1])
                    for prob in model1[corpus1]]
    lda_corpus_2 = [max(prob, key=lambda y:y[1])
                    for prob in model2[corpus1]]
    positive = 0
    negative = 0
    upper_limit = len(lda_corpus_1)
    total_permutations = upper_limit * \
        (upper_limit-1)/2  # nC2 combinations
    for i in range(upper_limit):
        for j in range(i+1, upper_limit):
            if(lda_corpus_1[i][0] == lda_corpus_1[j][0] and lda_corpus_2[i][0] == lda_corpus_2[j][0]):
                positive = positive+1
            elif(lda_corpus_1[i][0] != lda_corpus_1[j][0] and lda_corpus_2[i][0] == lda_corpus_2[j][0]):
                negative = negative+1
            elif(lda_corpus_1[i][0] == lda_corpus_1[j][0] and lda_corpus_2[i][0] != lda_corpus_2[j][0]):
                negative = negative+1
            elif(lda_corpus_1[i][0] != lda_corpus_1[j][0] and lda_corpus_2[i][0] != lda_corpus_2[j][0]):
                positive = positive+1
    answers_positive = (round(positive*100/total_permutations, 2))
    return answers_positive

# %%
f = open('temp.pkl','wb')
for i in range(10,150):
# for i in range(2,3):
    df = pd.DataFrame(columns=['positive_value','index','k'])
    for j in range(1,30):
#     for j in range(32,34):
        print('Loop Parameters-',(i,j))
        doc_params = get_doc_parameters(i,j)
        positive = get_positives_arr(doc_params[0],doc_params[1:])
        pickle.dump(((i,j),positive),f)
        df = add_row_to_df(df,positive,j)
        
        fig, ax = plt.subplots()
        sns_plot = sns.violinplot(x = 'k', y = 'positive_value', data = df)
        sns_plot = sns.pointplot(x='k', y='positive_value', data=df.groupby('k', as_index=False).median(), ax=ax, color='k', linestyle='--')

        plt.savefig("./temp/initial_"+str(i)+".eps")
        
        print('-----------------------------------------------')
    df.to_csv(r'./temp/inital_'+str(i)+'.csv')
f.close()
# Out:
# Loop Parameters- (10, 1)
# Progress upto Document no. 599 / 22179
# No. of New Docs: 64
# MODEL NO:1
# MODEL DONE
# Progress upto Document no. 632 / 22179
# No. of New Docs: 33
# MODEL NO:2
# MODEL DONE
# Progress upto Document no. 677 / 22179
# No. of New Docs: 45
# MODEL NO:3
# MODEL DONE
# Progress upto Document no. 695 / 22179
# No. of New Docs: 18
# MODEL NO:4
# MODEL DONE
# Progress upto Document no. 711 / 22179
# No. of New Docs: 16
# MODEL NO:5
# MODEL DONE
# Progress upto Document no. 733 / 22179
# No. of New Docs: 22
# MODEL NO:6
# MODEL DONE
# Progress upto Document no. 771 / 22179
# No. of New Docs: 38
# MODEL NO:7
# MODEL DONE
# Progress upto Document no. 808 / 22179
# No. of New Docs: 37
# MODEL NO:8
# MODEL DONE
# Progress upto Document no. 836 / 22179
# No. of New Docs: 28
# MODEL NO:9
# MODEL DONE
# Progress upto Document no. 861 / 22179
# No. of New Docs: 25
# MODEL NO:10
# MODEL DONE
# Progress upto Document no. 1012 / 22179
# No. of New Docs: 151
# MODEL NO:11
# MODEL DONE
# Progress upto Document no. 1179 / 22179
# No. of New Docs: 167
# MODEL NO:12
# MODEL DONE
# Progress upto Document no. 1284 / 22179
# No. of New Docs: 105
# MODEL NO:13
# MODEL DONE
# Progress upto Document no. 1360 / 22179
# No. of New Docs: 76
# MODEL NO:14
# MODEL DONE
# Progress upto Document no. 1415 / 22179
# No. of New Docs: 55
# MODEL NO:15
# MODEL DONE
# Progress upto Document no. 1446 / 22179
# No. of New Docs: 31
# MODEL NO:16
# MODEL DONE
# Progress upto Document no. 1498 / 22179
# No. of New Docs: 52
# MODEL NO:17
# MODEL DONE
# Progress upto Document no. 1520 / 22179
# No. of New Docs: 22
# MODEL NO:18
# MODEL DONE
# Progress upto Document no. 1546 / 22179
# No. of New Docs: 26
# MODEL NO:19
# MODEL DONE
# Progress upto Document no. 1580 / 22179
# No. of New Docs: 34
# MODEL NO:20
# MODEL DONE
# Progress upto Document no. 1599 / 22179
# No. of New Docs: 19
# MODEL NO:21
# MODEL DONE
# Progress upto Document no. 1615 / 22179
# No. of New Docs: 16
# MODEL NO:22
# MODEL DONE
# Progress upto Document no. 1641 / 22179
# No. of New Docs: 26
# MODEL NO:23
# MODEL DONE
# Progress upto Document no. 1654 / 22179
# No. of New Docs: 13
# MODEL NO:24
# MODEL DONE
# Progress upto Document no. 1681 / 22179
# No. of New Docs: 27
# MODEL NO:25
# MODEL DONE
# Progress upto Document no. 1702 / 22179
# No. of New Docs: 21
# MODEL NO:26
# MODEL DONE
# Progress upto Document no. 1720 / 22179
# No. of New Docs: 18
# MODEL NO:27
# MODEL DONE
# Progress upto Document no. 1764 / 22179
# No. of New Docs: 44
# MODEL NO:28
# MODEL DONE
# Progress upto Document no. 1797 / 22179
# No. of New Docs: 33
# MODEL NO:29
# MODEL DONE
# Progress upto Document no. 1826 / 22179
# No. of New Docs: 29
# MODEL NO:30
# MODEL DONE
# Progress upto Document no. 1925 / 22179
# No. of New Docs: 99
# MODEL NO:31
# MODEL DONE
# Progress upto Document no. 1954 / 22179
# No. of New Docs: 29
# MODEL NO:32
# MODEL DONE
# Progress upto Document no. 1975 / 22179
# No. of New Docs: 21
# MODEL NO:33
# MODEL DONE
# Progress upto Document no. 2012 / 22179
# No. of New Docs: 37
# MODEL NO:34
# MODEL DONE
# Progress upto Document no. 2057 / 22179
# No. of New Docs: 45
# MODEL NO:35
# MODEL DONE
# Progress upto Document no. 2077 / 22179
# No. of New Docs: 20
# MODEL NO:36
# MODEL DONE
# Progress upto Document no. 2101 / 22179
# No. of New Docs: 24
# MODEL NO:37
# MODEL DONE
# Progress upto Document no. 2123 / 22179
# No. of New Docs: 22
# MODEL NO:38
# MODEL DONE
# Progress upto Document no. 2155 / 22179
# No. of New Docs: 32
# MODEL NO:39
# MODEL DONE
# Progress upto Document no. 2177 / 22179
# No. of New Docs: 22
# MODEL NO:40
# MODEL DONE
# Progress upto Document no. 2195 / 22179
# No. of New Docs: 18
# MODEL NO:41
# MODEL DONE
# Progress upto Document no. 2220 / 22179
# No. of New Docs: 25
# MODEL NO:42
# MODEL DONE
# Progress upto Document no. 2241 / 22179
# No. of New Docs: 21
# MODEL NO:43
# MODEL DONE
# Progress upto Document no. 2279 / 22179
# No. of New Docs: 38
# MODEL NO:44
# MODEL DONE
# Progress upto Document no. 2303 / 22179
# No. of New Docs: 24
# MODEL NO:45
# MODEL DONE
# Progress upto Document no. 2357 / 22179
# No. of New Docs: 54
# MODEL NO:46
# MODEL DONE
# Progress upto Document no. 2368 / 22179
# No. of New Docs: 11
# MODEL NO:47
# MODEL DONE
# Progress upto Document no. 2388 / 22179
# No. of New Docs: 20
# MODEL NO:48
# MODEL DONE
# Progress upto Document no. 2413 / 22179
# No. of New Docs: 25
# MODEL NO:49
# MODEL DONE
# Progress upto Document no. 2431 / 22179
# No. of New Docs: 18
# MODEL NO:50
# MODEL DONE
# Progress upto Document no. 2462 / 22179
# No. of New Docs: 31
# MODEL NO:51
# MODEL DONE
# Progress upto Document no. 2521 / 22179
# No. of New Docs: 59
# MODEL NO:52
# MODEL DONE
# Progress upto Document no. 2607 / 22179
# No. of New Docs: 86
# MODEL NO:53
# MODEL DONE
# Progress upto Document no. 2623 / 22179
# No. of New Docs: 16
# MODEL NO:54
# MODEL DONE
# Progress upto Document no. 2642 / 22179
# No. of New Docs: 19
# MODEL NO:55
# MODEL DONE
# Progress upto Document no. 2679 / 22179
# No. of New Docs: 37
# MODEL NO:56
# MODEL DONE
# Progress upto Document no. 2718 / 22179
# No. of New Docs: 39
# MODEL NO:57
# MODEL DONE
# Progress upto Document no. 2763 / 22179
# No. of New Docs: 45
# MODEL NO:58
# MODEL DONE
# Progress upto Document no. 2792 / 22179
# No. of New Docs: 29
# MODEL NO:59
# MODEL DONE
# Progress upto Document no. 2835 / 22179
# No. of New Docs: 43
# MODEL NO:60
# MODEL DONE
# Progress upto Document no. 2879 / 22179
# No. of New Docs: 44
# MODEL NO:61
# MODEL DONE
# Progress upto Document no. 3015 / 22179
# No. of New Docs: 136
# MODEL NO:62
# MODEL DONE
# Progress upto Document no. 3084 / 22179
# No. of New Docs: 69
# MODEL NO:63
# MODEL DONE
# Progress upto Document no. 3131 / 22179
# No. of New Docs: 47
# MODEL NO:64
# MODEL DONE
# Progress upto Document no. 3189 / 22179
# No. of New Docs: 58
# MODEL NO:65
# MODEL DONE
# Progress upto Document no. 3222 / 22179
# No. of New Docs: 33
# MODEL NO:66
# MODEL DONE
# Progress upto Document no. 3319 / 22179
# No. of New Docs: 97
# MODEL NO:67
# MODEL DONE
# Progress upto Document no. 3357 / 22179
# No. of New Docs: 38
# MODEL NO:68
# MODEL DONE
# Progress upto Document no. 3395 / 22179
# No. of New Docs: 38
# MODEL NO:69
# MODEL DONE
# Progress upto Document no. 3426 / 22179
# No. of New Docs: 31
# MODEL NO:70
# MODEL DONE
# Progress upto Document no. 3489 / 22179
# No. of New Docs: 63
# MODEL NO:71
# MODEL DONE
# Progress upto Document no. 3601 / 22179
# No. of New Docs: 112
# MODEL NO:72
# MODEL DONE
# Progress upto Document no. 3653 / 22179
# No. of New Docs: 52
# MODEL NO:73
# MODEL DONE
# Progress upto Document no. 3683 / 22179
# No. of New Docs: 30
# MODEL NO:74
# MODEL DONE
# Progress upto Document no. 3743 / 22179
# No. of New Docs: 60
# MODEL NO:75
# MODEL DONE
# Progress upto Document no. 3789 / 22179
# No. of New Docs: 46
# MODEL NO:76
# MODEL DONE
# Progress upto Document no. 3857 / 22179
# No. of New Docs: 68
# MODEL NO:77
# MODEL DONE
# Progress upto Document no. 4006 / 22179
# No. of New Docs: 149
# MODEL NO:78
# MODEL DONE
# Progress upto Document no. 4079 / 22179
# No. of New Docs: 73
# MODEL NO:79
# MODEL DONE
# Progress upto Document no. 4137 / 22179
# No. of New Docs: 58
# MODEL NO:80
# MODEL DONE
# Progress upto Document no. 4160 / 22179
# No. of New Docs: 23
# MODEL NO:81
# MODEL DONE
# Progress upto Document no. 4188 / 22179
# No. of New Docs: 28
# MODEL NO:82
# MODEL DONE
# Progress upto Document no. 4220 / 22179
# No. of New Docs: 32
# MODEL NO:83
# MODEL DONE
# Progress upto Document no. 4271 / 22179
# No. of New Docs: 51
# MODEL NO:84
# MODEL DONE
# Progress upto Document no. 4336 / 22179
# No. of New Docs: 65
# MODEL NO:85
# MODEL DONE
# Progress upto Document no. 4499 / 22179
# No. of New Docs: 163
# MODEL NO:86
# MODEL DONE
# Progress upto Document no. 4681 / 22179
# No. of New Docs: 182
# MODEL NO:87
# MODEL DONE
# Progress upto Document no. 4783 / 22179
# No. of New Docs: 102
# MODEL NO:88
# MODEL DONE
# Progress upto Document no. 4859 / 22179
# No. of New Docs: 76
# MODEL NO:89
# MODEL DONE
# Progress upto Document no. 4904 / 22179
# No. of New Docs: 45
# MODEL NO:90
# MODEL DONE
# Progress upto Document no. 4956 / 22179
# No. of New Docs: 52
# MODEL NO:91
# MODEL DONE
# Progress upto Document no. 5041 / 22179
# No. of New Docs: 85
# MODEL NO:92
# MODEL DONE
# Progress upto Document no. 5223 / 22179
# No. of New Docs: 182
# MODEL NO:93
# MODEL DONE
# Progress upto Document no. 5399 / 22179
# No. of New Docs: 176
# MODEL NO:94
# MODEL DONE
# Progress upto Document no. 5524 / 22179
# No. of New Docs: 125
# MODEL NO:95
# MODEL DONE
# Progress upto Document no. 5626 / 22179
# No. of New Docs: 102
# MODEL NO:96
# MODEL DONE
# Progress upto Document no. 5661 / 22179
# No. of New Docs: 35
# MODEL NO:97
# MODEL DONE
# Progress upto Document no. 5705 / 22179
# No. of New Docs: 44
# MODEL NO:98
# MODEL DONE
# Progress upto Document no. 5746 / 22179
# No. of New Docs: 41
# MODEL NO:99
# MODEL DONE
# Progress upto Document no. 5812 / 22179
# No. of New Docs: 66
# MODEL NO:100
# MODEL DONE
# Progress upto Document no. 5876 / 22179
# No. of New Docs: 64
# MODEL NO:101
# MODEL DONE
# Progress upto Document no. 6023 / 22179
# No. of New Docs: 147
# MODEL NO:102
# MODEL DONE
# Progress upto Document no. 6421 / 22179
# No. of New Docs: 398
# MODEL NO:103
# MODEL DONE
# Progress upto Document no. 6620 / 22179
# No. of New Docs: 199
# MODEL NO:104
# MODEL DONE
# Progress upto Document no. 6796 / 22179
# No. of New Docs: 176
# MODEL NO:105
# MODEL DONE
# Progress upto Document no. 6922 / 22179
# No. of New Docs: 126
# MODEL NO:106
# MODEL DONE
# Progress upto Document no. 7055 / 22179
# No. of New Docs: 133
# MODEL NO:107
# MODEL DONE
# Progress upto Document no. 7147 / 22179
# No. of New Docs: 92
# MODEL NO:108
# MODEL DONE
# Progress upto Document no. 7269 / 22179
# No. of New Docs: 122
# MODEL NO:109
# MODEL DONE
# Progress upto Document no. 7423 / 22179
# No. of New Docs: 154
# MODEL NO:110
# MODEL DONE
# Progress upto Document no. 7548 / 22179
# No. of New Docs: 125
# MODEL NO:111
# MODEL DONE
# Progress upto Document no. 7692 / 22179
# No. of New Docs: 144
# MODEL NO:112
# MODEL DONE
# Progress upto Document no. 7825 / 22179
# No. of New Docs: 133
# MODEL NO:113
# MODEL DONE
# Progress upto Document no. 7960 / 22179
# No. of New Docs: 135
# MODEL NO:114
# MODEL DONE
# Progress upto Document no. 8114 / 22179
# No. of New Docs: 154
# MODEL NO:115
# MODEL DONE
# Progress upto Document no. 8275 / 22179
# No. of New Docs: 161
# MODEL NO:116
# MODEL DONE
# Progress upto Document no. 8402 / 22179
# No. of New Docs: 127
# MODEL NO:117
# MODEL DONE
# Progress upto Document no. 8555 / 22179
# No. of New Docs: 153
# MODEL NO:118
# MODEL DONE
# Progress upto Document no. 8748 / 22179
# No. of New Docs: 193
# MODEL NO:119
# MODEL DONE
# Progress upto Document no. 9034 / 22179
# No. of New Docs: 286
# MODEL NO:120
# MODEL DONE
# Progress upto Document no. 9210 / 22179
# No. of New Docs: 176
# MODEL NO:121
# MODEL DONE
# Progress upto Document no. 9400 / 22179
# No. of New Docs: 190
# MODEL NO:122
# MODEL DONE
# Progress upto Document no. 9604 / 22179
# No. of New Docs: 204
# MODEL NO:123
# MODEL DONE
# Progress upto Document no. 10030 / 22179
# No. of New Docs: 426
# MODEL NO:124
# MODEL DONE
# Progress upto Document no. 10517 / 22179
# No. of New Docs: 487
# MODEL NO:125
# MODEL DONE
# Progress upto Document no. 11223 / 22179
# No. of New Docs: 706
# MODEL NO:126
# MODEL DONE
# Progress upto Document no. 13321 / 22179
# No. of New Docs: 2098
# MODEL NO:127
# MODEL DONE
# Progress upto Document no. 13898 / 22179
# No. of New Docs: 577
# MODEL NO:128
# MODEL DONE
# Progress upto Document no. 14269 / 22179
# No. of New Docs: 371
# MODEL NO:129
# MODEL DONE
# Progress upto Document no. 14568 / 22179
# No. of New Docs: 299
# MODEL NO:130
# MODEL DONE
# Progress upto Document no. 14789 / 22179
# No. of New Docs: 221
# MODEL NO:131
# MODEL DONE
# Progress upto Document no. 15114 / 22179
# No. of New Docs: 325
# MODEL NO:132
# MODEL DONE
# Progress upto Document no. 15433 / 22179
# No. of New Docs: 319
# MODEL NO:133
# MODEL DONE
# Progress upto Document no. 15891 / 22179
# No. of New Docs: 458
# MODEL NO:134
# MODEL DONE
# Progress upto Document no. 16198 / 22179
# No. of New Docs: 307
# MODEL NO:135
# MODEL DONE
# Progress upto Document no. 16728 / 22179
# No. of New Docs: 530
# MODEL NO:136
# MODEL DONE
# Progress upto Document no. 16994 / 22179
# No. of New Docs: 266
# MODEL NO:137
# MODEL DONE
# Progress upto Document no. 17146 / 22179
# No. of New Docs: 152
# MODEL NO:138
# MODEL DONE
# Progress upto Document no. 17312 / 22179
# No. of New Docs: 166
# MODEL NO:139
# MODEL DONE
# Progress upto Document no. 17594 / 22179
# No. of New Docs: 282
# MODEL NO:140
# MODEL DONE
# Progress upto Document no. 17943 / 22179
# No. of New Docs: 349
# MODEL NO:141
# MODEL DONE
# Progress upto Document no. 18207 / 22179
# No. of New Docs: 264
# MODEL NO:142
# MODEL DONE
# Progress upto Document no. 18370 / 22179
# No. of New Docs: 163
# MODEL NO:143
# MODEL DONE
# Progress upto Document no. 18480 / 22179
# No. of New Docs: 110
# MODEL NO:144
# MODEL DONE
# Progress upto Document no. 18630 / 22179
# No. of New Docs: 150
# MODEL NO:145
# MODEL DONE
# Progress upto Document no. 18744 / 22179
# No. of New Docs: 114
# MODEL NO:146
# MODEL DONE
# Progress upto Document no. 18860 / 22179
# No. of New Docs: 116
# MODEL NO:147
# MODEL DONE
# Progress upto Document no. 19013 / 22179
# No. of New Docs: 153
# MODEL NO:148
# MODEL DONE
# Progress upto Document no. 19171 / 22179
# No. of New Docs: 158
# MODEL NO:149
# MODEL DONE
# Progress upto Document no. 19334 / 22179
# No. of New Docs: 163
# MODEL NO:150
# MODEL DONE
# Progress upto Document no. 19514 / 22179
# No. of New Docs: 180
# MODEL NO:151
# MODEL DONE
# Progress upto Document no. 19581 / 22179
# No. of New Docs: 67
# MODEL NO:152
# MODEL DONE
# Progress upto Document no. 19618 / 22179
# No. of New Docs: 37
# MODEL NO:153
# MODEL DONE
# Progress upto Document no. 19665 / 22179
# No. of New Docs: 47
# MODEL NO:154
# MODEL DONE
# Progress upto Document no. 19714 / 22179
# No. of New Docs: 49
# MODEL NO:155
# MODEL DONE
# Progress upto Document no. 19769 / 22179
# No. of New Docs: 55
# MODEL NO:156
# MODEL DONE
# Progress upto Document no. 19832 / 22179
# No. of New Docs: 63
# MODEL NO:157
# MODEL DONE
# Progress upto Document no. 19873 / 22179
# No. of New Docs: 41
# MODEL NO:158
# MODEL DONE
# Progress upto Document no. 19944 / 22179
# No. of New Docs: 71
# MODEL NO:159
# MODEL DONE
# Progress upto Document no. 20027 / 22179
# No. of New Docs: 83
# MODEL NO:160
# MODEL DONE
# Progress upto Document no. 20103 / 22179
# No. of New Docs: 76
# MODEL NO:161
# MODEL DONE
# Progress upto Document no. 20214 / 22179
# No. of New Docs: 111
# MODEL NO:162
# MODEL DONE
# Progress upto Document no. 20366 / 22179
# No. of New Docs: 152
# MODEL NO:163
# MODEL DONE
# Progress upto Document no. 20509 / 22179
# No. of New Docs: 143
# MODEL NO:164
# MODEL DONE
# Progress upto Document no. 20607 / 22179
# No. of New Docs: 98
# MODEL NO:165
# MODEL DONE
# Progress upto Document no. 20724 / 22179
# No. of New Docs: 117
# MODEL NO:166
# MODEL DONE
# Progress upto Document no. 20836 / 22179
# No. of New Docs: 112
# MODEL NO:167
# MODEL DONE
# Progress upto Document no. 20905 / 22179
# No. of New Docs: 69
# MODEL NO:168
# MODEL DONE
# Progress upto Document no. 20942 / 22179
# No. of New Docs: 37
# MODEL NO:169
# MODEL DONE
# Progress upto Document no. 21075 / 22179
# No. of New Docs: 133
# MODEL NO:170
# MODEL DONE
# Progress upto Document no. 21169 / 22179
# No. of New Docs: 94
# MODEL NO:171
# MODEL DONE
# Progress upto Document no. 21276 / 22179
# No. of New Docs: 107
# MODEL NO:172
# MODEL DONE
# Progress upto Document no. 21382 / 22179
# No. of New Docs: 106
# MODEL NO:173
# MODEL DONE
# Progress upto Document no. 21429 / 22179
# No. of New Docs: 47
# MODEL NO:174
# MODEL DONE
# Progress upto Document no. 21503 / 22179
# No. of New Docs: 74
# MODEL NO:175
# MODEL DONE
# Progress upto Document no. 21638 / 22179
# No. of New Docs: 135
# MODEL NO:176
# MODEL DONE
# Progress upto Document no. 21823 / 22179
# No. of New Docs: 185
# MODEL NO:177
# MODEL DONE
# Progress upto Document no. 21903 / 22179
# No. of New Docs: 80
# MODEL NO:178
# MODEL DONE
# Progress upto Document no. 21995 / 22179
# No. of New Docs: 92
# MODEL NO:179
# MODEL DONE
# Progress upto Document no. 22159 / 22179
# No. of New Docs: 164
# -----------------------------------------------
# Loop Parameters- (10, 2)
# Progress upto Document no. 632 / 22179
# No. of New Docs: 97
# MODEL NO:1
# MODEL DONE
# Progress upto Document no. 677 / 22179
# No. of New Docs: 45
# MODEL NO:2
# MODEL DONE
# Progress upto Document no. 695 / 22179
# No. of New Docs: 18
# MODEL NO:3
# MODEL DONE
# Progress upto Document no. 711 / 22179
# No. of New Docs: 16
# MODEL NO:4
# MODEL DONE
# Progress upto Document no. 733 / 22179
# No. of New Docs: 22
# MODEL NO:5
# MODEL DONE
# Progress upto Document no. 771 / 22179
# No. of New Docs: 38
# MODEL NO:6
# MODEL DONE
# Progress upto Document no. 808 / 22179
# No. of New Docs: 37
# MODEL NO:7
# MODEL DONE
# Progress upto Document no. 836 / 22179
# No. of New Docs: 28
# MODEL NO:8
# MODEL DONE
# Progress upto Document no. 861 / 22179
# No. of New Docs: 25
# MODEL NO:9
# MODEL DONE
# Progress upto Document no. 1012 / 22179
# No. of New Docs: 151
# MODEL NO:10
# MODEL DONE
# Progress upto Document no. 1179 / 22179
# No. of New Docs: 167
# MODEL NO:11
# MODEL DONE
# Progress upto Document no. 1284 / 22179
# No. of New Docs: 105
# MODEL NO:12
# MODEL DONE
# Progress upto Document no. 1360 / 22179
# No. of New Docs: 76
# MODEL NO:13
# MODEL DONE
# Progress upto Document no. 1415 / 22179
# No. of New Docs: 55
# MODEL NO:14
# MODEL DONE
# Progress upto Document no. 1446 / 22179
# No. of New Docs: 31
# MODEL NO:15
# MODEL DONE
# Progress upto Document no. 1498 / 22179
# No. of New Docs: 52
# MODEL NO:16
# MODEL DONE
# Progress upto Document no. 1520 / 22179
# No. of New Docs: 22
# MODEL NO:17
# MODEL DONE
# Progress upto Document no. 1546 / 22179
# No. of New Docs: 26
# MODEL NO:18
# MODEL DONE
# Progress upto Document no. 1580 / 22179
# No. of New Docs: 34
# MODEL NO:19
# MODEL DONE
# Progress upto Document no. 1599 / 22179
# No. of New Docs: 19
# MODEL NO:20
# MODEL DONE
# Progress upto Document no. 1615 / 22179
# No. of New Docs: 16
# MODEL NO:21
# MODEL DONE
# Progress upto Document no. 1641 / 22179
# No. of New Docs: 26
# MODEL NO:22
# MODEL DONE
# Progress upto Document no. 1654 / 22179
# No. of New Docs: 13
# MODEL NO:23
# MODEL DONE
# Progress upto Document no. 1681 / 22179
# No. of New Docs: 27
# MODEL NO:24
# MODEL DONE
# Progress upto Document no. 1702 / 22179
# No. of New Docs: 21
# MODEL NO:25
# MODEL DONE
# Progress upto Document no. 1720 / 22179
# No. of New Docs: 18
# MODEL NO:26
# MODEL DONE
# Progress upto Document no. 1764 / 22179
# No. of New Docs: 44
# MODEL NO:27
# MODEL DONE
# Progress upto Document no. 1797 / 22179
# No. of New Docs: 33
# MODEL NO:28
# MODEL DONE
# Progress upto Document no. 1826 / 22179
# No. of New Docs: 29
# MODEL NO:29
# MODEL DONE
# Progress upto Document no. 1925 / 22179
# No. of New Docs: 99
# MODEL NO:30
# MODEL DONE
# Progress upto Document no. 1954 / 22179
# No. of New Docs: 29
# MODEL NO:31
# MODEL DONE
# Progress upto Document no. 1975 / 22179
# No. of New Docs: 21
# MODEL NO:32
# MODEL DONE
# Progress upto Document no. 2012 / 22179
# No. of New Docs: 37
# MODEL NO:33
# MODEL DONE
# Progress upto Document no. 2057 / 22179
# No. of New Docs: 45
# MODEL NO:34
# MODEL DONE
# Progress upto Document no. 2077 / 22179
# No. of New Docs: 20
# MODEL NO:35
# MODEL DONE
# Progress upto Document no. 2101 / 22179
# No. of New Docs: 24
# MODEL NO:36
# MODEL DONE
# Progress upto Document no. 2123 / 22179
# No. of New Docs: 22
# MODEL NO:37
# MODEL DONE
# Progress upto Document no. 2155 / 22179
# No. of New Docs: 32
# MODEL NO:38
# MODEL DONE
# Progress upto Document no. 2177 / 22179
# No. of New Docs: 22
# MODEL NO:39
# MODEL DONE
# Progress upto Document no. 2195 / 22179
# No. of New Docs: 18
# MODEL NO:40
# MODEL DONE
# Progress upto Document no. 2220 / 22179
# No. of New Docs: 25
# MODEL NO:41
# MODEL DONE
# Progress upto Document no. 2241 / 22179
# No. of New Docs: 21
# MODEL NO:42
# MODEL DONE
# Progress upto Document no. 2279 / 22179
# No. of New Docs: 38
# MODEL NO:43
# MODEL DONE
# Progress upto Document no. 2303 / 22179
# No. of New Docs: 24
# MODEL NO:44
# MODEL DONE
# Progress upto Document no. 2357 / 22179
# No. of New Docs: 54
# MODEL NO:45
# MODEL DONE
# Progress upto Document no. 2368 / 22179
# No. of New Docs: 11
# MODEL NO:46
# MODEL DONE
# Progress upto Document no. 2388 / 22179
# No. of New Docs: 20
# MODEL NO:47
# MODEL DONE
# Progress upto Document no. 2413 / 22179
# No. of New Docs: 25
# MODEL NO:48
# MODEL DONE
# Progress upto Document no. 2431 / 22179
# No. of New Docs: 18
# MODEL NO:49
# MODEL DONE
# Progress upto Document no. 2462 / 22179
# No. of New Docs: 31
# MODEL NO:50
# MODEL DONE
# Progress upto Document no. 2521 / 22179
# No. of New Docs: 59
# MODEL NO:51
# MODEL DONE
# Progress upto Document no. 2607 / 22179
# No. of New Docs: 86
# MODEL NO:52
# MODEL DONE
# Progress upto Document no. 2623 / 22179
# No. of New Docs: 16
# MODEL NO:53
# MODEL DONE
# Progress upto Document no. 2642 / 22179
# No. of New Docs: 19
# MODEL NO:54
# MODEL DONE
# Progress upto Document no. 2679 / 22179
# No. of New Docs: 37
# MODEL NO:55
# MODEL DONE
# Progress upto Document no. 2718 / 22179
# No. of New Docs: 39
# MODEL NO:56
# MODEL DONE
# Progress upto Document no. 2763 / 22179
# No. of New Docs: 45
# MODEL NO:57
# MODEL DONE
# Progress upto Document no. 2792 / 22179
# No. of New Docs: 29
# MODEL NO:58
# MODEL DONE
# Progress upto Document no. 2835 / 22179
# No. of New Docs: 43
# MODEL NO:59
# MODEL DONE
# Progress upto Document no. 2879 / 22179
# No. of New Docs: 44
# MODEL NO:60
# MODEL DONE
# Progress upto Document no. 3015 / 22179
# No. of New Docs: 136
# MODEL NO:61
# MODEL DONE
# Progress upto Document no. 3084 / 22179
# No. of New Docs: 69
# MODEL NO:62
# MODEL DONE
# Progress upto Document no. 3131 / 22179
# No. of New Docs: 47
# MODEL NO:63
# MODEL DONE
# Progress upto Document no. 3189 / 22179
# No. of New Docs: 58
# MODEL NO:64
# MODEL DONE
# Progress upto Document no. 3222 / 22179
# No. of New Docs: 33
# MODEL NO:65
# MODEL DONE
# Progress upto Document no. 3319 / 22179
# No. of New Docs: 97
# MODEL NO:66
# MODEL DONE
# Progress upto Document no. 3357 / 22179
# No. of New Docs: 38
# MODEL NO:67
# MODEL DONE
# Progress upto Document no. 3395 / 22179
# No. of New Docs: 38
# MODEL NO:68
# MODEL DONE
# Progress upto Document no. 3426 / 22179
# No. of New Docs: 31
# MODEL NO:69
# MODEL DONE
# Progress upto Document no. 3489 / 22179
# No. of New Docs: 63
# MODEL NO:70
# MODEL DONE
# Progress upto Document no. 3601 / 22179
# No. of New Docs: 112
# MODEL NO:71
# MODEL DONE
# Progress upto Document no. 3653 / 22179
# No. of New Docs: 52
# MODEL NO:72
# MODEL DONE
# Progress upto Document no. 3683 / 22179
# No. of New Docs: 30
# MODEL NO:73
# MODEL DONE
# Progress upto Document no. 3743 / 22179
# No. of New Docs: 60
# MODEL NO:74
# MODEL DONE
# Progress upto Document no. 3789 / 22179
# No. of New Docs: 46
# MODEL NO:75
# MODEL DONE
# Progress upto Document no. 3857 / 22179
# No. of New Docs: 68
# MODEL NO:76
# MODEL DONE
# Progress upto Document no. 4006 / 22179
# No. of New Docs: 149
# MODEL NO:77
# MODEL DONE
# Progress upto Document no. 4079 / 22179
# No. of New Docs: 73
# MODEL NO:78
# MODEL DONE
# Progress upto Document no. 4137 / 22179
# No. of New Docs: 58
# MODEL NO:79
# MODEL DONE
# Progress upto Document no. 4160 / 22179
# No. of New Docs: 23
# MODEL NO:80
# MODEL DONE
# Progress upto Document no. 4188 / 22179
# No. of New Docs: 28
# MODEL NO:81
# MODEL DONE
# Progress upto Document no. 4220 / 22179
# No. of New Docs: 32
# MODEL NO:82
# MODEL DONE
# Progress upto Document no. 4271 / 22179
# No. of New Docs: 51
# MODEL NO:83
# MODEL DONE
# Progress upto Document no. 4336 / 22179
# No. of New Docs: 65
# MODEL NO:84
# MODEL DONE
# Progress upto Document no. 4499 / 22179
# No. of New Docs: 163
# MODEL NO:85
# MODEL DONE
# Progress upto Document no. 4681 / 22179
# No. of New Docs: 182
# MODEL NO:86
# MODEL DONE
# Progress upto Document no. 4783 / 22179
# No. of New Docs: 102
# MODEL NO:87
# MODEL DONE
# Progress upto Document no. 4859 / 22179
# No. of New Docs: 76
# MODEL NO:88
# MODEL DONE
# Progress upto Document no. 4904 / 22179
# No. of New Docs: 45
# MODEL NO:89
# MODEL DONE
# Progress upto Document no. 4956 / 22179
# No. of New Docs: 52
# MODEL NO:90
# MODEL DONE
# Progress upto Document no. 5041 / 22179
# No. of New Docs: 85
# MODEL NO:91
# MODEL DONE
# Progress upto Document no. 5223 / 22179
# No. of New Docs: 182
# MODEL NO:92
# MODEL DONE
# Progress upto Document no. 5399 / 22179
# No. of New Docs: 176
# MODEL NO:93
# MODEL DONE
# Progress upto Document no. 5524 / 22179
# No. of New Docs: 125
# MODEL NO:94
# MODEL DONE
# Progress upto Document no. 5626 / 22179
# No. of New Docs: 102
# MODEL NO:95
# MODEL DONE
# Progress upto Document no. 5661 / 22179
# No. of New Docs: 35
# MODEL NO:96
# MODEL DONE
# Progress upto Document no. 5705 / 22179
# No. of New Docs: 44
# MODEL NO:97
# MODEL DONE
# Progress upto Document no. 5746 / 22179
# No. of New Docs: 41
# MODEL NO:98
# MODEL DONE
# Progress upto Document no. 5812 / 22179
# No. of New Docs: 66
# MODEL NO:99
# MODEL DONE
# Progress upto Document no. 5876 / 22179
# No. of New Docs: 64
# MODEL NO:100
# MODEL DONE
# Progress upto Document no. 6023 / 22179
# No. of New Docs: 147
# MODEL NO:101
# MODEL DONE
# Progress upto Document no. 6421 / 22179
# No. of New Docs: 398
# MODEL NO:102
# MODEL DONE
# Progress upto Document no. 6620 / 22179
# No. of New Docs: 199
# MODEL NO:103
# MODEL DONE
# Progress upto Document no. 6796 / 22179
# No. of New Docs: 176
# MODEL NO:104
# MODEL DONE
# Progress upto Document no. 6922 / 22179
# No. of New Docs: 126
# MODEL NO:105
# MODEL DONE
# Progress upto Document no. 7055 / 22179
# No. of New Docs: 133
# MODEL NO:106
# MODEL DONE
# Progress upto Document no. 7147 / 22179
# No. of New Docs: 92
# MODEL NO:107
# MODEL DONE
# Progress upto Document no. 7269 / 22179
# No. of New Docs: 122
# MODEL NO:108
# MODEL DONE
# Progress upto Document no. 7423 / 22179
# No. of New Docs: 154
# MODEL NO:109
# MODEL DONE
# Progress upto Document no. 7548 / 22179
# No. of New Docs: 125
# MODEL NO:110
# MODEL DONE
# Progress upto Document no. 7692 / 22179
# No. of New Docs: 144
# MODEL NO:111
# MODEL DONE
# Progress upto Document no. 7825 / 22179
# No. of New Docs: 133
# MODEL NO:112
# MODEL DONE
# Progress upto Document no. 7960 / 22179
# No. of New Docs: 135
# MODEL NO:113
# MODEL DONE
# Progress upto Document no. 8114 / 22179
# No. of New Docs: 154
# MODEL NO:114
# MODEL DONE
# Progress upto Document no. 8275 / 22179
# No. of New Docs: 161
# MODEL NO:115
# MODEL DONE
# Progress upto Document no. 8402 / 22179
# No. of New Docs: 127
# MODEL NO:116
# MODEL DONE
# Progress upto Document no. 8555 / 22179
# No. of New Docs: 153
# MODEL NO:117
# MODEL DONE
# Progress upto Document no. 8748 / 22179
# No. of New Docs: 193
# MODEL NO:118
# MODEL DONE
# Progress upto Document no. 9034 / 22179
# No. of New Docs: 286
# MODEL NO:119
# MODEL DONE
# Progress upto Document no. 9210 / 22179
# No. of New Docs: 176
# MODEL NO:120
# MODEL DONE
# Progress upto Document no. 9400 / 22179
# No. of New Docs: 190
# MODEL NO:121
# MODEL DONE
# Progress upto Document no. 9604 / 22179
# No. of New Docs: 204
# MODEL NO:122
# MODEL DONE
# Progress upto Document no. 10030 / 22179
# No. of New Docs: 426
# MODEL NO:123
# MODEL DONE
# Progress upto Document no. 10517 / 22179
# No. of New Docs: 487
# MODEL NO:124
# MODEL DONE
# Progress upto Document no. 11223 / 22179
# No. of New Docs: 706
# MODEL NO:125
# MODEL DONE
# Progress upto Document no. 13321 / 22179
# No. of New Docs: 2098
# MODEL NO:126
# MODEL DONE
# Progress upto Document no. 13898 / 22179
# No. of New Docs: 577
# MODEL NO:127
# MODEL DONE
# Progress upto Document no. 14269 / 22179
# No. of New Docs: 371
# MODEL NO:128
# MODEL DONE
# Progress upto Document no. 14568 / 22179
# No. of New Docs: 299
# MODEL NO:129
# MODEL DONE
# Progress upto Document no. 14789 / 22179
# No. of New Docs: 221
# MODEL NO:130
# MODEL DONE
# Progress upto Document no. 15114 / 22179
# No. of New Docs: 325
# MODEL NO:131
# MODEL DONE
# Progress upto Document no. 15433 / 22179
# No. of New Docs: 319
# MODEL NO:132
# MODEL DONE
# Progress upto Document no. 15891 / 22179
# No. of New Docs: 458
# MODEL NO:133
# MODEL DONE
# Progress upto Document no. 16198 / 22179
# No. of New Docs: 307
# MODEL NO:134
# MODEL DONE
# Progress upto Document no. 16728 / 22179
# No. of New Docs: 530
# MODEL NO:135
# MODEL DONE
# Progress upto Document no. 16994 / 22179
# No. of New Docs: 266
# MODEL NO:136
# MODEL DONE
# Progress upto Document no. 17146 / 22179
# No. of New Docs: 152
# MODEL NO:137
# MODEL DONE
# Progress upto Document no. 17312 / 22179
# No. of New Docs: 166
# MODEL NO:138
# MODEL DONE
# Progress upto Document no. 17594 / 22179
# No. of New Docs: 282
# MODEL NO:139
# MODEL DONE
# Progress upto Document no. 17943 / 22179
# No. of New Docs: 349
# MODEL NO:140
# MODEL DONE
# Progress upto Document no. 18207 / 22179
# No. of New Docs: 264
# MODEL NO:141
# MODEL DONE
# Progress upto Document no. 18370 / 22179
# No. of New Docs: 163
# MODEL NO:142
# MODEL DONE
# Progress upto Document no. 18480 / 22179
# No. of New Docs: 110
# MODEL NO:143
# MODEL DONE
# Progress upto Document no. 18630 / 22179
# No. of New Docs: 150
# MODEL NO:144
# MODEL DONE
# Progress upto Document no. 18744 / 22179
# No. of New Docs: 114
# MODEL NO:145
# MODEL DONE
# Progress upto Document no. 18860 / 22179
# No. of New Docs: 116
# MODEL NO:146
# MODEL DONE
# Progress upto Document no. 19013 / 22179
# No. of New Docs: 153
# MODEL NO:147
# MODEL DONE
# Progress upto Document no. 19171 / 22179
# No. of New Docs: 158
# MODEL NO:148
# MODEL DONE
# Progress upto Document no. 19334 / 22179
# No. of New Docs: 163
# MODEL NO:149
# MODEL DONE
# Progress upto Document no. 19514 / 22179
# No. of New Docs: 180
# MODEL NO:150
# MODEL DONE
# Progress upto Document no. 19581 / 22179
# No. of New Docs: 67
# MODEL NO:151
# MODEL DONE
# Progress upto Document no. 19618 / 22179
# No. of New Docs: 37
# MODEL NO:152
# MODEL DONE
# Progress upto Document no. 19665 / 22179
# No. of New Docs: 47
# MODEL NO:153
# MODEL DONE
# Progress upto Document no. 19714 / 22179
# No. of New Docs: 49
# MODEL NO:154
# MODEL DONE
# Progress upto Document no. 19769 / 22179
# No. of New Docs: 55
# MODEL NO:155
# MODEL DONE
# Progress upto Document no. 19832 / 22179
# No. of New Docs: 63
# MODEL NO:156
# MODEL DONE
# Progress upto Document no. 19873 / 22179
# No. of New Docs: 41
# MODEL NO:157
# MODEL DONE
# Progress upto Document no. 19944 / 22179
# No. of New Docs: 71
# MODEL NO:158
# MODEL DONE
# Progress upto Document no. 20027 / 22179
# No. of New Docs: 83
# MODEL NO:159
# MODEL DONE
# Progress upto Document no. 20103 / 22179
# No. of New Docs: 76
# MODEL NO:160
# MODEL DONE
# Progress upto Document no. 20214 / 22179
# No. of New Docs: 111
# MODEL NO:161
# MODEL DONE
# Progress upto Document no. 20366 / 22179
# No. of New Docs: 152
# MODEL NO:162
# MODEL DONE
# Progress upto Document no. 20509 / 22179
# No. of New Docs: 143
# MODEL NO:163
# MODEL DONE
# Progress upto Document no. 20607 / 22179
# No. of New Docs: 98
# MODEL NO:164
# MODEL DONE
# Progress upto Document no. 20724 / 22179
# No. of New Docs: 117
# MODEL NO:165
# MODEL DONE
# Progress upto Document no. 20836 / 22179
# No. of New Docs: 112
# MODEL NO:166
# MODEL DONE
# Progress upto Document no. 20905 / 22179
# No. of New Docs: 69
# MODEL NO:167
# MODEL DONE
# Progress upto Document no. 20942 / 22179
# No. of New Docs: 37
# MODEL NO:168
# MODEL DONE
# Progress upto Document no. 21075 / 22179
# No. of New Docs: 133
# MODEL NO:169
# MODEL DONE
# Progress upto Document no. 21169 / 22179
# No. of New Docs: 94
# MODEL NO:170
# MODEL DONE
# Progress upto Document no. 21276 / 22179
# No. of New Docs: 107
# MODEL NO:171
# MODEL DONE
# Progress upto Document no. 21382 / 22179
# No. of New Docs: 106
# MODEL NO:172
# MODEL DONE
# Progress upto Document no. 21429 / 22179
# No. of New Docs: 47
# MODEL NO:173
# MODEL DONE
# Progress upto Document no. 21503 / 22179
# No. of New Docs: 74
# MODEL NO:174
# MODEL DONE
# Progress upto Document no. 21638 / 22179
# No. of New Docs: 135
# MODEL NO:175
# MODEL DONE
# Progress upto Document no. 21823 / 22179
# No. of New Docs: 185
# MODEL NO:176
# MODEL DONE
# Progress upto Document no. 21903 / 22179
# No. of New Docs: 80
# MODEL NO:177
# MODEL DONE
# Progress upto Document no. 21995 / 22179
# No. of New Docs: 92
# MODEL NO:178
# MODEL DONE
# Progress upto Document no. 22159 / 22179
# No. of New Docs: 164
# -----------------------------------------------
# Loop Parameters- (10, 3)
# Progress upto Document no. 677 / 22179
# No. of New Docs: 142
# MODEL NO:1
# MODEL DONE
# Progress upto Document no. 711 / 22179
# No. of New Docs: 34
# MODEL NO:2
# MODEL DONE
# Progress upto Document no. 771 / 22179
# No. of New Docs: 60
# MODEL NO:3
# MODEL DONE
# Progress upto Document no. 836 / 22179
# No. of New Docs: 65
# MODEL NO:4
# MODEL DONE
# Progress upto Document no. 1012 / 22179
# No. of New Docs: 176
# MODEL NO:5
# MODEL DONE
# Progress upto Document no. 1284 / 22179
# No. of New Docs: 272
# MODEL NO:6
# MODEL DONE
# Progress upto Document no. 1415 / 22179
# No. of New Docs: 131
# MODEL NO:7
# MODEL DONE
# Progress upto Document no. 1498 / 22179
# No. of New Docs: 83
# MODEL NO:8
# MODEL DONE
# Progress upto Document no. 1546 / 22179
# No. of New Docs: 48
# MODEL NO:9
# MODEL DONE
# Progress upto Document no. 1599 / 22179
# No. of New Docs: 53
# MODEL NO:10
# MODEL DONE
# Progress upto Document no. 1641 / 22179
# No. of New Docs: 42
# MODEL NO:11
# MODEL DONE
# Progress upto Document no. 1681 / 22179
# No. of New Docs: 40
# MODEL NO:12
# MODEL DONE
# Progress upto Document no. 1720 / 22179
# No. of New Docs: 39
# MODEL NO:13
# MODEL DONE
# Progress upto Document no. 1797 / 22179
# No. of New Docs: 77
# MODEL NO:14
# MODEL DONE
# Progress upto Document no. 1925 / 22179
# No. of New Docs: 128
# MODEL NO:15
# MODEL DONE
# Progress upto Document no. 1975 / 22179
# No. of New Docs: 50
# MODEL NO:16
# MODEL DONE
# Progress upto Document no. 2057 / 22179
# No. of New Docs: 82
# MODEL NO:17
# MODEL DONE
# Progress upto Document no. 2101 / 22179
# No. of New Docs: 44
# MODEL NO:18
# MODEL DONE
# Progress upto Document no. 2155 / 22179
# No. of New Docs: 54
# MODEL NO:19
# MODEL DONE
# Progress upto Document no. 2195 / 22179
# No. of New Docs: 40
# MODEL NO:20
# MODEL DONE
# Progress upto Document no. 2241 / 22179
# No. of New Docs: 46
# MODEL NO:21
# MODEL DONE
# Progress upto Document no. 2303 / 22179
# No. of New Docs: 62
# MODEL NO:22
# MODEL DONE
# Progress upto Document no. 2368 / 22179
# No. of New Docs: 65
# MODEL NO:23
# MODEL DONE
# Progress upto Document no. 2413 / 22179
# No. of New Docs: 45
# MODEL NO:24
# MODEL DONE
# Progress upto Document no. 2462 / 22179
# No. of New Docs: 49
# MODEL NO:25
# MODEL DONE
# Progress upto Document no. 2607 / 22179
# No. of New Docs: 145
# MODEL NO:26
# MODEL DONE
# Progress upto Document no. 2642 / 22179
# No. of New Docs: 35
# MODEL NO:27
# MODEL DONE
# Progress upto Document no. 2718 / 22179
# No. of New Docs: 76
# MODEL NO:28
# MODEL DONE
# Progress upto Document no. 2792 / 22179
# No. of New Docs: 74
# MODEL NO:29
# MODEL DONE
# Progress upto Document no. 2879 / 22179
# No. of New Docs: 87
# MODEL NO:30
# MODEL DONE
# Progress upto Document no. 3084 / 22179
# No. of New Docs: 205
# MODEL NO:31
# MODEL DONE
# Progress upto Document no. 3189 / 22179
# No. of New Docs: 105
# MODEL NO:32
# MODEL DONE
# Progress upto Document no. 3319 / 22179
# No. of New Docs: 130
# MODEL NO:33
# MODEL DONE
# Progress upto Document no. 3395 / 22179
# No. of New Docs: 76
# MODEL NO:34
# MODEL DONE
# Progress upto Document no. 3489 / 22179
# No. of New Docs: 94
# MODEL NO:35
# MODEL DONE
# Progress upto Document no. 3653 / 22179
# No. of New Docs: 164
# MODEL NO:36
# MODEL DONE
# Progress upto Document no. 3743 / 22179
# No. of New Docs: 90
# MODEL NO:37
# MODEL DONE
# Progress upto Document no. 3857 / 22179
# No. of New Docs: 114
# MODEL NO:38
# MODEL DONE
# Progress upto Document no. 4079 / 22179
# No. of New Docs: 222
# MODEL NO:39
# MODEL DONE
# Progress upto Document no. 4160 / 22179
# No. of New Docs: 81
# MODEL NO:40
# MODEL DONE
# Progress upto Document no. 4220 / 22179
# No. of New Docs: 60
# MODEL NO:41
# MODEL DONE
# Progress upto Document no. 4336 / 22179
# No. of New Docs: 116
# MODEL NO:42
# MODEL DONE
# Progress upto Document no. 4681 / 22179
# No. of New Docs: 345
# MODEL NO:43
# MODEL DONE
# Progress upto Document no. 4859 / 22179
# No. of New Docs: 178
# MODEL NO:44
# MODEL DONE
# Progress upto Document no. 4956 / 22179
# No. of New Docs: 97
# MODEL NO:45
# MODEL DONE
# Progress upto Document no. 5223 / 22179
# No. of New Docs: 267
# MODEL NO:46
# MODEL DONE
# Progress upto Document no. 5524 / 22179
# No. of New Docs: 301
# MODEL NO:47
# MODEL DONE
# Progress upto Document no. 5661 / 22179
# No. of New Docs: 137
# MODEL NO:48
# MODEL DONE
# Progress upto Document no. 5746 / 22179
# No. of New Docs: 85
# MODEL NO:49
# MODEL DONE
# Progress upto Document no. 5876 / 22179
# No. of New Docs: 130
# MODEL NO:50
# MODEL DONE
# Progress upto Document no. 6421 / 22179
# No. of New Docs: 545
# MODEL NO:51
# MODEL DONE
# Progress upto Document no. 6796 / 22179
# No. of New Docs: 375
# MODEL NO:52
# MODEL DONE
# Progress upto Document no. 7055 / 22179
# No. of New Docs: 259
# MODEL NO:53
# MODEL DONE
# Progress upto Document no. 7269 / 22179
# No. of New Docs: 214
# MODEL NO:54
# MODEL DONE
# Progress upto Document no. 7548 / 22179
# No. of New Docs: 279
# MODEL NO:55
# MODEL DONE
# Progress upto Document no. 7825 / 22179
# No. of New Docs: 277
# MODEL NO:56
# MODEL DONE
# Progress upto Document no. 8114 / 22179
# No. of New Docs: 289
# MODEL NO:57
# MODEL DONE
# Progress upto Document no. 8402 / 22179
# No. of New Docs: 288
# MODEL NO:58
# MODEL DONE
# Progress upto Document no. 8748 / 22179
# No. of New Docs: 346
# MODEL NO:59
# MODEL DONE
# Progress upto Document no. 9210 / 22179
# No. of New Docs: 462
# MODEL NO:60
# MODEL DONE
# Progress upto Document no. 9604 / 22179
# No. of New Docs: 394
# MODEL NO:61
# MODEL DONE
# Progress upto Document no. 10517 / 22179
# No. of New Docs: 913
# MODEL NO:62
# MODEL DONE
# Progress upto Document no. 13321 / 22179
# No. of New Docs: 2804
# MODEL NO:63
# MODEL DONE
# Progress upto Document no. 14269 / 22179
# No. of New Docs: 948
# MODEL NO:64
# MODEL DONE
# Progress upto Document no. 14789 / 22179
# No. of New Docs: 520
# MODEL NO:65
# MODEL DONE
# Progress upto Document no. 15433 / 22179
# No. of New Docs: 644
# MODEL NO:66
# MODEL DONE
# Progress upto Document no. 16198 / 22179
# No. of New Docs: 765
# MODEL NO:67
# MODEL DONE
# Progress upto Document no. 16994 / 22179
# No. of New Docs: 796
# MODEL NO:68
# MODEL DONE
# Progress upto Document no. 17312 / 22179
# No. of New Docs: 318
# MODEL NO:69
# MODEL DONE
# Progress upto Document no. 17943 / 22179
# No. of New Docs: 631
# MODEL NO:70
# MODEL DONE
# Progress upto Document no. 18370 / 22179
# No. of New Docs: 427
# MODEL NO:71
# MODEL DONE
# Progress upto Document no. 18630 / 22179
# No. of New Docs: 260
# MODEL NO:72
# MODEL DONE
# Progress upto Document no. 18860 / 22179
# No. of New Docs: 230
# MODEL NO:73
# MODEL DONE
# Progress upto Document no. 19171 / 22179
# No. of New Docs: 311
# MODEL NO:74
# MODEL DONE
# Progress upto Document no. 19514 / 22179
# No. of New Docs: 343
# MODEL NO:75
# MODEL DONE
# Progress upto Document no. 19618 / 22179
# No. of New Docs: 104
# MODEL NO:76
# MODEL DONE
# Progress upto Document no. 19714 / 22179
# No. of New Docs: 96
# MODEL NO:77
# MODEL DONE
# Progress upto Document no. 19832 / 22179
# No. of New Docs: 118
# MODEL NO:78
# MODEL DONE
# Progress upto Document no. 19944 / 22179
# No. of New Docs: 112
# MODEL NO:79
# MODEL DONE
# Progress upto Document no. 20103 / 22179
# No. of New Docs: 159
# MODEL NO:80
# MODEL DONE
# Progress upto Document no. 20366 / 22179
# No. of New Docs: 263
# MODEL NO:81
# MODEL DONE
# Progress upto Document no. 20607 / 22179
# No. of New Docs: 241
# MODEL NO:82
# MODEL DONE
# Progress upto Document no. 20836 / 22179
# No. of New Docs: 229
# MODEL NO:83
# MODEL DONE
# Progress upto Document no. 20942 / 22179
# No. of New Docs: 106
# MODEL NO:84
# MODEL DONE
# Progress upto Document no. 21169 / 22179
# No. of New Docs: 227
# MODEL NO:85
# MODEL DONE
# Progress upto Document no. 21382 / 22179
# No. of New Docs: 213
# MODEL NO:86
# MODEL DONE
# Progress upto Document no. 21503 / 22179
# No. of New Docs: 121
# MODEL NO:87
# MODEL DONE
# Progress upto Document no. 21823 / 22179
# No. of New Docs: 320
# MODEL NO:88
# MODEL DONE
# Progress upto Document no. 21995 / 22179
# No. of New Docs: 172
# -----------------------------------------------
# Loop Parameters- (10, 4)
# Progress upto Document no. 695 / 22179
# No. of New Docs: 160
# MODEL NO:1
# MODEL DONE
# Progress upto Document no. 771 / 22179
# No. of New Docs: 76
# MODEL NO:2
# MODEL DONE
# Progress upto Document no. 861 / 22179
# No. of New Docs: 90
# MODEL NO:3
# MODEL DONE
# Progress upto Document no. 1284 / 22179
# No. of New Docs: 423
# MODEL NO:4
# MODEL DONE
# Progress upto Document no. 1446 / 22179
# No. of New Docs: 162
# MODEL NO:5
# MODEL DONE
# Progress upto Document no. 1546 / 22179
# No. of New Docs: 100
# MODEL NO:6
# MODEL DONE
# Progress upto Document no. 1615 / 22179
# No. of New Docs: 69
# MODEL NO:7
# MODEL DONE
# Progress upto Document no. 1681 / 22179
# No. of New Docs: 66
# MODEL NO:8
# MODEL DONE
# Progress upto Document no. 1764 / 22179
# No. of New Docs: 83
# MODEL NO:9
# MODEL DONE
# Progress upto Document no. 1925 / 22179
# No. of New Docs: 161
# MODEL NO:10
# MODEL DONE
# Progress upto Document no. 2012 / 22179
# No. of New Docs: 87
# MODEL NO:11
# MODEL DONE
# Progress upto Document no. 2101 / 22179
# No. of New Docs: 89
# MODEL NO:12
# MODEL DONE
# Progress upto Document no. 2177 / 22179
# No. of New Docs: 76
# MODEL NO:13
# MODEL DONE
# Progress upto Document no. 2241 / 22179
# No. of New Docs: 64
# MODEL NO:14
# MODEL DONE
# Progress upto Document no. 2357 / 22179
# No. of New Docs: 116
# MODEL NO:15
# MODEL DONE
# Progress upto Document no. 2413 / 22179
# No. of New Docs: 56
# MODEL NO:16
# MODEL DONE
# Progress upto Document no. 2521 / 22179
# No. of New Docs: 108
# MODEL NO:17
# MODEL DONE
# Progress upto Document no. 2642 / 22179
# No. of New Docs: 121
# MODEL NO:18
# MODEL DONE
# Progress upto Document no. 2763 / 22179
# No. of New Docs: 121
# MODEL NO:19
# MODEL DONE
# Progress upto Document no. 2879 / 22179
# No. of New Docs: 116
# MODEL NO:20
# MODEL DONE
# Progress upto Document no. 3131 / 22179
# No. of New Docs: 252
# MODEL NO:21
# MODEL DONE
# Progress upto Document no. 3319 / 22179
# No. of New Docs: 188
# MODEL NO:22
# MODEL DONE
# Progress upto Document no. 3426 / 22179
# No. of New Docs: 107
# MODEL NO:23
# MODEL DONE
# Progress upto Document no. 3653 / 22179
# No. of New Docs: 227
# MODEL NO:24
# MODEL DONE
# Progress upto Document no. 3789 / 22179
# No. of New Docs: 136
# MODEL NO:25
# MODEL DONE
# Progress upto Document no. 4079 / 22179
# No. of New Docs: 290
# MODEL NO:26
# MODEL DONE
# Progress upto Document no. 4188 / 22179
# No. of New Docs: 109
# MODEL NO:27
# MODEL DONE
# Progress upto Document no. 4336 / 22179
# No. of New Docs: 148
# MODEL NO:28
# MODEL DONE
# Progress upto Document no. 4783 / 22179
# No. of New Docs: 447
# MODEL NO:29
# MODEL DONE
# Progress upto Document no. 4956 / 22179
# No. of New Docs: 173
# MODEL NO:30
# MODEL DONE
# Progress upto Document no. 5399 / 22179
# No. of New Docs: 443
# MODEL NO:31
# MODEL DONE
# Progress upto Document no. 5661 / 22179
# No. of New Docs: 262
# MODEL NO:32
# MODEL DONE
# Progress upto Document no. 5812 / 22179
# No. of New Docs: 151
# MODEL NO:33
# MODEL DONE
# Progress upto Document no. 6421 / 22179
# No. of New Docs: 609
# MODEL NO:34
# MODEL DONE
# Progress upto Document no. 6922 / 22179
# No. of New Docs: 501
# MODEL NO:35
# MODEL DONE
# Progress upto Document no. 7269 / 22179
# No. of New Docs: 347
# MODEL NO:36
# MODEL DONE
# Progress upto Document no. 7692 / 22179
# No. of New Docs: 423
# MODEL NO:37
# MODEL DONE
# Progress upto Document no. 8114 / 22179
# No. of New Docs: 422
# MODEL NO:38
# MODEL DONE
# Progress upto Document no. 8555 / 22179
# No. of New Docs: 441
# MODEL NO:39
# MODEL DONE
# Progress upto Document no. 9210 / 22179
# No. of New Docs: 655
# MODEL NO:40
# MODEL DONE
# Progress upto Document no. 10030 / 22179
# No. of New Docs: 820
# MODEL NO:41
# MODEL DONE
# Progress upto Document no. 13321 / 22179
# No. of New Docs: 3291
# MODEL NO:42
# MODEL DONE
# Progress upto Document no. 14568 / 22179
# No. of New Docs: 1247
# MODEL NO:43
# MODEL DONE
# Progress upto Document no. 15433 / 22179
# No. of New Docs: 865
# MODEL NO:44
# MODEL DONE
# Progress upto Document no. 16728 / 22179
# No. of New Docs: 1295
# MODEL NO:45
# MODEL DONE
# Progress upto Document no. 17312 / 22179
# No. of New Docs: 584
# MODEL NO:46
# MODEL DONE
# Progress upto Document no. 18207 / 22179
# No. of New Docs: 895
# MODEL NO:47
# MODEL DONE
# Progress upto Document no. 18630 / 22179
# No. of New Docs: 423
# MODEL NO:48
# MODEL DONE
# Progress upto Document no. 19013 / 22179
# No. of New Docs: 383
# MODEL NO:49
# MODEL DONE
# Progress upto Document no. 19514 / 22179
# No. of New Docs: 501
# MODEL NO:50
# MODEL DONE
# Progress upto Document no. 19665 / 22179
# No. of New Docs: 151
# MODEL NO:51
# MODEL DONE
# Progress upto Document no. 19832 / 22179
# No. of New Docs: 167
# MODEL NO:52
# MODEL DONE
# Progress upto Document no. 20027 / 22179
# No. of New Docs: 195
# MODEL NO:53
# MODEL DONE
# Progress upto Document no. 20366 / 22179
# No. of New Docs: 339
# MODEL NO:54
# MODEL DONE
# Progress upto Document no. 20724 / 22179
# No. of New Docs: 358
# MODEL NO:55
# MODEL DONE
# Progress upto Document no. 20942 / 22179
# No. of New Docs: 218
# MODEL NO:56
# MODEL DONE
# Progress upto Document no. 21276 / 22179
# No. of New Docs: 334
# MODEL NO:57
# MODEL DONE
# Progress upto Document no. 21503 / 22179
# No. of New Docs: 227
# MODEL NO:58
# MODEL DONE
# Progress upto Document no. 21903 / 22179
# No. of New Docs: 400
# -----------------------------------------------
# Loop Parameters- (10, 5)
# Progress upto Document no. 711 / 22179
# No. of New Docs: 176
# MODEL NO:1
# MODEL DONE
# Progress upto Document no. 836 / 22179
# No. of New Docs: 125
# MODEL NO:2
# MODEL DONE
# Progress upto Document no. 1284 / 22179
# No. of New Docs: 448
# MODEL NO:3
# MODEL DONE
# Progress upto Document no. 1498 / 22179
# No. of New Docs: 214
# MODEL NO:4
# MODEL DONE
# Progress upto Document no. 1599 / 22179
# No. of New Docs: 101
# MODEL NO:5
# MODEL DONE
# Progress upto Document no. 1681 / 22179
# No. of New Docs: 82
# MODEL NO:6
# MODEL DONE
# Progress upto Document no. 1797 / 22179
# No. of New Docs: 116
# MODEL NO:7
# MODEL DONE
# Progress upto Document no. 1975 / 22179
# No. of New Docs: 178
# MODEL NO:8
# MODEL DONE
# Progress upto Document no. 2101 / 22179
# No. of New Docs: 126
# MODEL NO:9
# MODEL DONE
# Progress upto Document no. 2195 / 22179
# No. of New Docs: 94
# MODEL NO:10
# MODEL DONE
# Progress upto Document no. 2303 / 22179
# No. of New Docs: 108
# MODEL NO:11
# MODEL DONE
# Progress upto Document no. 2413 / 22179
# No. of New Docs: 110
# MODEL NO:12
# MODEL DONE
# Progress upto Document no. 2607 / 22179
# No. of New Docs: 194
# MODEL NO:13
# MODEL DONE
# Progress upto Document no. 2718 / 22179
# No. of New Docs: 111
# MODEL NO:14
# MODEL DONE
# Progress upto Document no. 2879 / 22179
# No. of New Docs: 161
# MODEL NO:15
# MODEL DONE
# Progress upto Document no. 3189 / 22179
# No. of New Docs: 310
# MODEL NO:16
# MODEL DONE
# Progress upto Document no. 3395 / 22179
# No. of New Docs: 206
# MODEL NO:17
# MODEL DONE
# Progress upto Document no. 3653 / 22179
# No. of New Docs: 258
# MODEL NO:18
# MODEL DONE
# Progress upto Document no. 3857 / 22179
# No. of New Docs: 204
# MODEL NO:19
# MODEL DONE
# Progress upto Document no. 4160 / 22179
# No. of New Docs: 303
# MODEL NO:20
# MODEL DONE
# Progress upto Document no. 4336 / 22179
# No. of New Docs: 176
# MODEL NO:21
# MODEL DONE
# Progress upto Document no. 4859 / 22179
# No. of New Docs: 523
# MODEL NO:22
# MODEL DONE
# Progress upto Document no. 5223 / 22179
# No. of New Docs: 364
# MODEL NO:23
# MODEL DONE
# Progress upto Document no. 5661 / 22179
# No. of New Docs: 438
# MODEL NO:24
# MODEL DONE
# Progress upto Document no. 5876 / 22179
# No. of New Docs: 215
# MODEL NO:25
# MODEL DONE
# Progress upto Document no. 6796 / 22179
# No. of New Docs: 920
# MODEL NO:26
# MODEL DONE
# Progress upto Document no. 7269 / 22179
# No. of New Docs: 473
# MODEL NO:27
# MODEL DONE
# Progress upto Document no. 7825 / 22179
# No. of New Docs: 556
# MODEL NO:28
# MODEL DONE
# Progress upto Document no. 8402 / 22179
# No. of New Docs: 577
# MODEL NO:29
# MODEL DONE
# Progress upto Document no. 9210 / 22179
# No. of New Docs: 808
# MODEL NO:30
# MODEL DONE
# Progress upto Document no. 10517 / 22179
# No. of New Docs: 1307
# MODEL NO:31
# MODEL DONE
# Progress upto Document no. 14269 / 22179
# No. of New Docs: 3752
# MODEL NO:32
# MODEL DONE
# Progress upto Document no. 15433 / 22179
# No. of New Docs: 1164
# MODEL NO:33
# MODEL DONE
# Progress upto Document no. 16994 / 22179
# No. of New Docs: 1561
# MODEL NO:34
# MODEL DONE
# Progress upto Document no. 17943 / 22179
# No. of New Docs: 949
# MODEL NO:35
# MODEL DONE
# Progress upto Document no. 18630 / 22179
# No. of New Docs: 687
# MODEL NO:36
# MODEL DONE
# Progress upto Document no. 19171 / 22179
# No. of New Docs: 541
# MODEL NO:37
# MODEL DONE
# Progress upto Document no. 19618 / 22179
# No. of New Docs: 447
# MODEL NO:38
# MODEL DONE
# Progress upto Document no. 19832 / 22179
# No. of New Docs: 214
# MODEL NO:39
# MODEL DONE
# Progress upto Document no. 20103 / 22179
# No. of New Docs: 271
# MODEL NO:40
# MODEL DONE
# Progress upto Document no. 20607 / 22179
# No. of New Docs: 504
# MODEL NO:41
# MODEL DONE
# Progress upto Document no. 20942 / 22179
# No. of New Docs: 335
# MODEL NO:42
# MODEL DONE
# Progress upto Document no. 21382 / 22179
# No. of New Docs: 440
# MODEL NO:43
# MODEL DONE
# Progress upto Document no. 21823 / 22179
# No. of New Docs: 441
# -----------------------------------------------
# Loop Parameters- (10, 6)
# Progress upto Document no. 733 / 22179
# No. of New Docs: 198
# MODEL NO:1
# MODEL DONE
# Progress upto Document no. 1012 / 22179
# No. of New Docs: 279
# MODEL NO:2
# MODEL DONE
# Progress upto Document no. 1446 / 22179
# No. of New Docs: 434
# MODEL NO:3
# MODEL DONE
# Progress upto Document no. 1599 / 22179
# No. of New Docs: 153
# MODEL NO:4
# MODEL DONE
# Progress upto Document no. 1702 / 22179
# No. of New Docs: 103
# MODEL NO:5
# MODEL DONE
# Progress upto Document no. 1925 / 22179
# No. of New Docs: 223
# MODEL NO:6
# MODEL DONE
# Progress upto Document no. 2077 / 22179
# No. of New Docs: 152
# MODEL NO:7
# MODEL DONE
# Progress upto Document no. 2195 / 22179
# No. of New Docs: 118
# MODEL NO:8
# MODEL DONE
# Progress upto Document no. 2357 / 22179
# No. of New Docs: 162
# MODEL NO:9
# MODEL DONE
# Progress upto Document no. 2462 / 22179
# No. of New Docs: 105
# MODEL NO:10
# MODEL DONE
# Progress upto Document no. 2679 / 22179
# No. of New Docs: 217
# MODEL NO:11
# MODEL DONE
# Progress upto Document no. 2879 / 22179
# No. of New Docs: 200
# MODEL NO:12
# MODEL DONE
# Progress upto Document no. 3222 / 22179
# No. of New Docs: 343
# MODEL NO:13
# MODEL DONE
# Progress upto Document no. 3489 / 22179
# No. of New Docs: 267
# MODEL NO:14
# MODEL DONE
# Progress upto Document no. 3789 / 22179
# No. of New Docs: 300
# MODEL NO:15
# MODEL DONE
# Progress upto Document no. 4160 / 22179
# No. of New Docs: 371
# MODEL NO:16
# MODEL DONE
# Progress upto Document no. 4499 / 22179
# No. of New Docs: 339
# MODEL NO:17
# MODEL DONE
# ...
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "/usr/local/lib/python3.7/site-packages/gensim/models/ldamulticore.py", line 334, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "/usr/local/lib/python3.7/site-packages/gensim/models/ldamulticore.py", line 334, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-13736:
# Process ForkPoolWorker-13738:
# Process ForkPoolWorker-13733:
# Process ForkPoolWorker-13734:
# Process ForkPoolWorker-13735:
# Process ForkPoolWorker-13739:
# Process ForkPoolWorker-13737:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 105, in worker
#     initializer(*initargs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 105, in worker
#     initializer(*initargs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 105, in worker
#     initializer(*initargs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 105, in worker
#     initializer(*initargs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 105, in worker
#     initializer(*initargs)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 105, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.7/site-packages/gensim/models/ldamulticore.py", line 334, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/usr/local/lib/python3.7/site-packages/gensim/models/ldamulticore.py", line 334, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py", line 105, in worker
#     initializer(*initargs)
#   File "/usr/local/lib/python3.7/site-packages/gensim/models/ldamulticore.py", line 334, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/usr/local/lib/python3.7/site-packages/gensim/models/ldamulticore.py", line 334, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/usr/local/lib/python3.7/site-packages/gensim/models/ldamulticore.py", line 334, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/usr/local/lib/python3.7/site-packages/gensim/models/ldamulticore.py", line 334, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "/usr/local/lib/python3.7/site-packages/gensim/models/ldamulticore.py", line 334, in worker_e_step
#     chunk_no, chunk, worker_lda = input_queue.get()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 94, in get
#     res = self._recv_bytes()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/queues.py", line 93, in get
#     with self._rlock:
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-13749:
# Process ForkPoolWorker-13747:
# Process ForkPoolWorker-13746:
# Process ForkPoolWorker-13745:
# Process ForkPoolWorker-13744:
# Process ForkPoolWorker-13741:
# Process ForkPoolWorker-13751:
# Process ForkPoolWorker-13742:
# Process ForkPoolWorker-13748:
# Process ForkPoolWorker-13750:
# Process ForkPoolWorker-13743:
# Process ForkPoolWorker-13740:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()

# %% [markdown]
# Model built on 1 month data <br>
# Incremental updates done on 30*2 weeks data
