# %%
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# Summed up to middle
# * GST = 13*2 weeks = Approx 6 months
# * Aadhar = 1*2 weeks
#
# Started from middle
# * Farmers = 0
# * Demonetisation = 1*2 weeks

# %%
input = '../../data/temp/farmers_confusion.pkl'

with open(input,'rb') as f:
    while True:
        try:
            y,x = pickle.load(f)
        except:
            break

# %%
fig = plt.figure()
plt.title('Farmers Protest')
plt.axhline(90)
plt.xlabel('Time in units of 2 weeks')
plt.ylabel('Positive value from Confusion matrix')
plt.plot(y)
plt.savefig('farmers.eps',format='eps')

# %%
with open('../../data/preprocessed_data/doc_indexes/farmers.pkl','rb') as f:
    a,b,c = pickle.load(f)

# %%
temp=[]
temp.append(b)
temp.extend(c)

# %%
fig = plt.figure()
plt.xlabel('Time in units of 2 weeks')
plt.ylabel('No. of Documents recieved in given unit of time')
plt.title('Farmers protest')
plt.plot(temp)
plt.savefig('t_farmers.eps',format='eps')
